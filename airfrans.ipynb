# %%
# !pip install airfrans
# Out:
# Collecting airfrans
#   Downloading airfrans-0.1.5.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from airfrans) (2.0.2)
# Collecting pyvista>=0.37.0 (from airfrans)
#   Downloading pyvista-0.48.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from airfrans) (4.67.3)
# Collecting cyclopts>=4.0.0 (from pyvista>=0.37.0->airfrans)
#   Downloading cyclopts-4.20.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyvista>=0.37.0->airfrans) (3.10.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pyvista>=0.37.0->airfrans) (11.3.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from pyvista>=0.37.0->airfrans) (1.9.0)
# Requirement already satisfied: scooby>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from pyvista>=0.37.0->airfrans) (0.11.2)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from pyvista>=0.37.0->airfrans) (4.15.0)
# Collecting vtk!=9.4.0 (from pyvista>=0.37.0->airfrans)
#   Downloading vtk-9.6.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista>=0.37.0->airfrans) (26.1.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista>=0.37.0->airfrans) (0.18.0)
# Collecting rich-rst<3.0.0,>=1.3.1 (from cyclopts>=4.0.0->pyvista>=0.37.0->airfrans)
#   Downloading rich_rst-2.0.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: rich>=13.6.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista>=0.37.0->airfrans) (13.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->pyvista>=0.37.0->airfrans) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch->pyvista>=0.37.0->airfrans) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista>=0.37.0->airfrans) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista>=0.37.0->airfrans) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista>=0.37.0->airfrans) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista>=0.37.0->airfrans) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista>=0.37.0->airfrans) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista>=0.37.0->airfrans) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista>=0.37.0->airfrans) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->cyclopts>=4.0.0->pyvista>=0.37.0->airfrans) (0.1.2)
# Downloading airfrans-0.1.5.1-py3-none-any.whl (15 kB)
# Downloading pyvista-0.48.4-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 8.6 MB/s eta 0:00:00
# Downloading cyclopts-4.20.0-py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.4/229.4 kB 18.1 MB/s eta 0:00:00
# Downloading vtk-9.6.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (146.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 MB 7.4 MB/s eta 0:00:00
# Downloading rich_rst-2.0.2-py3-none-any.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.1/273.1 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: vtk, rich-rst, cyclopts, pyvista, airfrans
# Successfully installed airfrans-0.1.5.1 cyclopts-4.20.0 pyvista-0.48.4 rich-rst-2.0.2 vtk-9.6.2

# %%
import airfrans as af

af.dataset.download(root = ".", file_name = 'Dataset', unzip = True, OpenFOAM = False)
# Out:
# Downloading AirfRANS: 9.34GB [12:58, 12.9MB/s]
# Extracting Dataset.zip at ....

# %%
import airfrans as af
dataset_list, dataset_names = af.dataset.load(root="Dataset", task='full', train=True)
# Out:
# Loading dataset (task: full, split: train):  85%|████████▌ | 683/800 [03:32<01:16,  1.54it/s]
